# %%
#standard inputs
import numpy as np
import time as time
import sys

#custom imports
from mod.load_data import *

# %%
CLASSIFIED_IMAGE_DIR = 'classified_images/'

# %%
#pass classified images directory path and desired image dimension size

data, labels = load_gmaps_data(CLASSIFIED_IMAGE_DIR, 64)
# Out:
# Loaded 4 images in 0.1417 seconds
# Positive Images: 2
# Negative Images: 2
# Class Ratio: 0.5000

# %%
#
display_image(data, 2)
