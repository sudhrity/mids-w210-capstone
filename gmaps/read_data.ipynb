# %%
#standard inputs
import numpy as np
import time as time
import sys

#custom imports
from mod.load_data import *

# %%
CLASSIFIED_IMAGES_DIR = '.classified_images/'
NAME_CLASS_FILE = 'data_write/name_class.txt'

# %%
names, classes = get_classes(NAME_CLASS_FILE)
# Out:
# Returned 4 items to each list

# %%
names
# Out:
# ['34.08859216159822,-118.2932885212978.png',
#  '34.10306779481576,-118.2932885212978.png',
#  '34.08859216159822,-118.27581249050782.png',
#  '34.10306779481576,-118.27581249050782.png']

# %%
classes
# Out:
# [0, 1, 1, 0]

# %%
data = load_gmaps_images(CLASSIFIED_IMAGES_DIR, names)
# Out:
# 4 images loaded in 0.1216 seconds.

# %%
idx = np.random.randint(len(data))

display_image(3, data)

# %%
get_photo_array(idx, data)
# Out:
# array([[[0.58039216, 0.57941176, 0.59534314],
#         [0.57230392, 0.56936275, 0.59166667],
#         [0.61102941, 0.61102941, 0.62745098],
#         ...,
#         [0.23529412, 0.26666667, 0.38431373],
#         [0.23455882, 0.26593137, 0.37990196],
#         [0.23529412, 0.26666667, 0.38063725]],
#
#        [[0.58014706, 0.57696078, 0.59583333],
#         [0.57426471, 0.57058824, 0.58946078],
#         [0.57279412, 0.57181373, 0.58848039],
#         ...,
#         [0.23529412, 0.26666667, 0.38406863],
#         [0.22965686, 0.25808824, 0.37377451],
#         [0.22230392, 0.25294118, 0.35857843]],
#
#        [[0.61789216, 0.61397059, 0.63259804],
#         [0.5879902 , 0.58308824, 0.60220588],
#         [0.60122549, 0.59730392, 0.61715686],
#         ...,
#         [0.23455882, 0.26593137, 0.38333333],
#         [0.22034314, 0.25171569, 0.35931373],
#         [0.16568627, 0.19632353, 0.28627451]],
#
#        ...,
#
#        [[0.13137255, 0.15637255, 0.22598039],
# ...
