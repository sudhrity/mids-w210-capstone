# %%
#!pip install statsmodels

# %%
#!pip install psycopg2
# Out:
# Requirement already satisfied: psycopg2 in c:\users\jdayer\anaconda3\envs\lawn\lib\site-packages (2.9.3)

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm

# %%
import psycopg2

conn = psycopg2.connect(database="postgres",
                        host="18.204.57.173",
                        user="postgres",
                        password="&j>n!_nL]k&wWdE>*TVds4P6",
                        port="5432")

# %%
cursor = conn.cursor()

# %%
import pandas.io.sql as sqlio
data = sqlio.read_sql_query('SELECT * FROM \"public\".\"panel_zipcode_tf\"', conn)
# Now data is a pandas dataframe having the results of above query.
data.head()
# Out:
# C:\Users\jdayer\Anaconda3\envs\lawn\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#    id state              county zipcode city_neighborhood  year  polygon_area  \
# 0   1    CA  Los Angeles County   90001       Los Angeles  2010  3.073809e+06
# 1   2    CA  Los Angeles County   90002       Los Angeles  2010  3.286992e+06
# 2   3    CA  Los Angeles County   90003       Los Angeles  2010  3.708685e+06
# 3   4    CA  Los Angeles County   90004       Los Angeles  2010  3.737537e+06
# 4   5    CA  Los Angeles County   90005       Los Angeles  2010  1.524769e+06
#
#    water_area      lawn_area      tree_area  ...     soil_area  turf_area  \
# 0         0.0  536096.145294  419205.374676  ...  1.883450e+06        0.0
# 1         0.0  565103.085483  480626.848806  ...  1.869860e+06        0.0
# 2         0.0  493599.756755  402375.315911  ...  2.176462e+06        0.0
# 3         0.0  233807.175637  580552.334268  ...  1.942550e+06        0.0
# 4         0.0   69997.690573  253337.599360  ...  5.856309e+05        0.0
#
#    tree_ndvi_mean  tree_ndvi_max  tree_ndvi_min  grass_ndvi_mean  \
# 0        0.625616       0.243933       0.065868         0.585903
# 1        0.791209       0.253252       0.064039         0.743017
# 2        0.748344       0.241827       0.063584         0.644444
# 3        0.873418       0.287679       0.045977         0.940741
# 4        0.884774       0.310294       0.025126         0.957447
#
#    grass_ndvi_max  grass_ndvi_min  median_income  water_usage
# 0        0.224363       -0.569620        35097.0          0.0
# 1        0.239545       -0.862069        31258.0          0.0
# 2        0.226489        0.046358        29686.0          0.0
# 3        0.231025        0.037975        37976.0          0.0
# 4        0.230888       -0.035714        31893.0          0.0
#
# [5 rows x 22 columns]

# %%
# this does not have the right data for income
data[data['zipcode'] == '90001']
# Out:
#         id state              county zipcode city_neighborhood  year  \
# 0        1    CA  Los Angeles County   90001       Los Angeles  2010
# 262    263    CA  Los Angeles County   90001       Los Angeles  2012
# 524    525    CA  Los Angeles County   90001       Los Angeles  2014
# 786    787    CA  Los Angeles County   90001       Los Angeles  2016
# 1046  1047    CA  Los Angeles County   90001       Los Angeles  2018
# 1306  1432    CA  Los Angeles County   90001       Los Angeles  2020
#
#       polygon_area  water_area      lawn_area     tree_area  ...  \
# 0     3.073809e+06    0.000000  536096.145294  4.192054e+05  ...
# 262   3.073809e+06  842.119100   11430.651934  2.642042e+04  ...
# 524   3.073809e+06    0.000000   83215.524379  1.009638e+05  ...
# 786   3.073809e+06    0.000000   21728.297165  2.330775e+05  ...
# 1046  3.073809e+06  262.074998   22117.815213  5.836078e+04  ...
# 1306  8.878204e+06  661.678650  225107.597756  1.312926e+06  ...
#
#          soil_area    turf_area  tree_ndvi_mean  tree_ndvi_max  tree_ndvi_min  \
# 0     1.883450e+06     0.000000        0.625616       0.243933       0.065868
# 262   6.796880e+03  1721.959536        0.744444       0.378506       0.115044
# 524   1.520944e+05   567.049225        0.621359       0.337108       0.102410
# 786   5.101036e+05     0.000000        0.511312       0.230989       0.037037
# 1046  1.886759e+03   473.647506        0.636364       0.349815       0.112033
# 1306  1.636435e+06  9595.472107        0.693780       0.278618       0.040462
#
#       grass_ndvi_mean  grass_ndvi_max  grass_ndvi_min  median_income  \
# 0            0.585903        0.224363       -0.569620        35097.0
# 262          0.730570        0.451988        0.130742        35097.0
# 524          0.666667        0.313119        0.073333        35097.0
# 786          0.549180        0.262433        0.087500        35097.0
# 1046         0.644068        0.340483        0.100719        35097.0
# 1306         0.662100        0.245586        0.073171        35097.0
#
#       water_usage
# 0             0.0
# 262           0.0
# 524           0.0
# 786           0.0
# 1046          0.0
# 1306          0.0
#
# [6 rows x 22 columns]

# %%
data.columns
# Out:
# Index(['id', 'state', 'county', 'zipcode', 'city_neighborhood', 'year',
#        'polygon_area', 'water_area', 'lawn_area', 'tree_area', 'pv_area',
#        'impervious_area', 'soil_area', 'turf_area', 'tree_ndvi_mean',
#        'tree_ndvi_max', 'tree_ndvi_min', 'grass_ndvi_mean', 'grass_ndvi_max',
#        'grass_ndvi_min', 'median_income', 'water_usage'],
#       dtype='object')

# %% [markdown]
# ### Load Data

# %% [markdown]
# #### Load Landcover Data

# %%
lc = data[['zipcode','year','lawn_area','tree_area','polygon_area']]

# %%
lc = lc.sort_values(by=['zipcode','year'], ascending=True)

# %%
lc
# Out:
#      zipcode  year     lawn_area     tree_area  polygon_area
# 0      90001  2010  5.360961e+05  4.192054e+05  3.073809e+06
# 262    90001  2012  1.143065e+04  2.642042e+04  3.073809e+06
# 524    90001  2014  8.321552e+04  1.009638e+05  3.073809e+06
# 786    90001  2016  2.172830e+04  2.330775e+05  3.073809e+06
# 1046   90001  2018  2.211782e+04  5.836078e+04  3.073809e+06
# ...      ...   ...           ...           ...           ...
# 1305   93551  2018  2.526522e+06  3.684106e+06  6.507298e+07
# 1589   93552  2020  9.987008e+06  8.634139e+06  1.770726e+08
# 1590   93553  2020  3.218187e+05  5.229903e+07  1.477662e+08
# 1591   93563  2020  1.447706e+06  8.065865e+07  1.927201e+08
# 1592   93591  2020  6.673020e+06  3.750836e+06  2.419502e+08
#
# [1593 rows x 5 columns]

# %%
# creates simple variables for vegetation(trees & grass)
lc['vegetation_area'] = lc['lawn_area']+lc['tree_area']

# %%
# creates percentages for each class
lc['trees_%']=lc['tree_area']/lc['polygon_area']*100
lc['grass_%']=lc['lawn_area']/lc['polygon_area']*100
lc['vegetation_%']=lc['vegetation_area']/lc['polygon_area']*100

# %%
def diff_column(df,column_name):
    '''Calculates delta from the consecutive 2 year period for a zipcode and a class'''
    df[column_name + '_delta'] = df[column_name] - df.groupby(['zipcode'])[column_name].shift()
    return df

# %%
feature_list = ['trees_%',
                'grass_%',
                'vegetation_%']
for feature in feature_list:
    diff_column(lc, feature)

# %%
lc
# Out:
#      zipcode  year     lawn_area     tree_area  polygon_area  vegetation_area  \
# 0      90001  2010  5.360961e+05  4.192054e+05  3.073809e+06     9.553015e+05
# 262    90001  2012  1.143065e+04  2.642042e+04  3.073809e+06     3.785107e+04
# 524    90001  2014  8.321552e+04  1.009638e+05  3.073809e+06     1.841793e+05
# 786    90001  2016  2.172830e+04  2.330775e+05  3.073809e+06     2.548057e+05
# 1046   90001  2018  2.211782e+04  5.836078e+04  3.073809e+06     8.047859e+04
# ...      ...   ...           ...           ...           ...              ...
# 1305   93551  2018  2.526522e+06  3.684106e+06  6.507298e+07     6.210628e+06
# 1589   93552  2020  9.987008e+06  8.634139e+06  1.770726e+08     1.862115e+07
# 1590   93553  2020  3.218187e+05  5.229903e+07  1.477662e+08     5.262085e+07
# 1591   93563  2020  1.447706e+06  8.065865e+07  1.927201e+08     8.210635e+07
# 1592   93591  2020  6.673020e+06  3.750836e+06  2.419502e+08     1.042386e+07
#
#         trees_%    grass_%  vegetation_%  trees_%_delta  grass_%_delta  \
# 0     13.637978  17.440777     31.078754            NaN            NaN
# 262    0.859533   0.371873      1.231406     -12.778444     -17.068904
# 524    3.284647   2.707245      5.991892       2.425114       2.335372
# 786    7.582692   0.706885      8.289577       4.298045      -2.000359
# 1046   1.898647   0.719557      2.618204      -5.684045       0.012672
# ...         ...        ...           ...            ...            ...
# 1305   5.661499   3.882597      9.544096       2.135941       0.113645
# 1589   4.876044   5.640063     10.516107            NaN            NaN
# 1590  35.393087   0.217789     35.610876            NaN            NaN
# 1591  41.852735   0.751196     42.603930            NaN            NaN
# 1592   1.550251   2.758014      4.308265            NaN            NaN
#
#       vegetation_%_delta
# 0                    NaN
# 262           -29.847348
# 524             4.760486
# 786             2.297685
# 1046           -5.671373
# ...                  ...
# 1305            2.249586
# 1589                 NaN
# 1590                 NaN
# 1591                 NaN
# 1592                 NaN
#
# [1593 rows x 12 columns]

# %%
lc.hist(column='vegetation_%_delta')
# Out:
# array([[<AxesSubplot:title={'center':'vegetation_%_delta'}>]],
#       dtype=object)

# %%
lc.plot.scatter(x = 'polygon_area', y = 'vegetation_%_delta')
# Out:
# <AxesSubplot:xlabel='polygon_area', ylabel='vegetation_%_delta'>

# %%
#affluency = pd.read_csv('https://raw.githubusercontent.com/sudhrity/mids-w210-capstone/main/data/median_income.csv?token=GHSAT0AAAAAABSLF6ZX5AV5LWORMFQ23WQAYWEWKQQ')

# %%
#affluency.to_csv('affluency.csv')

# %%
affluency = pd.read_csv('affluency.csv')

# %%
aff = affluency.melt(id_vars =['zipcode'], value_vars =['y2010','y2012','y2014','y2016','y2018','y2020'])
aff['variable'] = aff['variable'].replace(['y2010','y2012','y2014','y2016','y2018','y2020'],['2010','2012','2014','2016','2018','2020'])
aff = aff.rename(columns = {'variable':'year', 'value':'median_income'})

# %%
aff
# Out:
#       zipcode  year  median_income
# 0       90001  2010        35097.0
# 1       90002  2010        31258.0
# 2       90003  2010        29686.0
# 3       90004  2010        37976.0
# 4       90005  2010        31893.0
# ...       ...   ...            ...
# 2905    93584  2020            NaN
# 2906    93586  2020            NaN
# 2907    93590  2020            NaN
# 2908    93591  2020        48911.0
# 2909    93599  2020            NaN
#
# [2910 rows x 3 columns]

# %%
def diff_column_aff(df,column_name):
    '''Calculates delta from the consecutive 2 year period for a zipcode and a class'''
    df[column_name + '_delta'] = df[column_name] - df.groupby(['zipcode'])[column_name].shift()
    return df

# %%
diff_column_aff(aff,'median_income')
# Out:
#       zipcode  year  median_income  median_income_delta
# 0       90001  2010        35097.0                  NaN
# 1       90002  2010        31258.0                  NaN
# 2       90003  2010        29686.0                  NaN
# 3       90004  2010        37976.0                  NaN
# 4       90005  2010        31893.0                  NaN
# ...       ...   ...            ...                  ...
# 2905    93584  2020            NaN                  NaN
# 2906    93586  2020            NaN                  NaN
# 2907    93590  2020            NaN                  NaN
# 2908    93591  2020        48911.0               2653.0
# 2909    93599  2020            NaN                  NaN
#
# [2910 rows x 4 columns]

# %%
lc['zipcode'] = lc['zipcode'].astype(int)

# %%
display(lc.dtypes)
# Out:
# zipcode                 int32
# year                   object
# lawn_area             float64
# tree_area             float64
# polygon_area          float64
# vegetation_area       float64
# trees_%               float64
# grass_%               float64
# vegetation_%          float64
# trees_%_delta         float64
# grass_%_delta         float64
# vegetation_%_delta    float64
# dtype: object

# %%
display(aff.dtypes)
# Out:
# zipcode                  int64
# year                    object
# median_income          float64
# median_income_delta    float64
# dtype: object

# %%
df = lc.merge(aff, left_on=['year','zipcode'], right_on=['year','zipcode'])

# %%
df
# Out:
#       zipcode  year     lawn_area     tree_area  polygon_area  \
# 0       90001  2010  5.360961e+05  4.192054e+05  3.073809e+06
# 1       90001  2012  1.143065e+04  2.642042e+04  3.073809e+06
# 2       90001  2014  8.321552e+04  1.009638e+05  3.073809e+06
# 3       90001  2016  2.172830e+04  2.330775e+05  3.073809e+06
# 4       90001  2018  2.211782e+04  5.836078e+04  3.073809e+06
# ...       ...   ...           ...           ...           ...
# 1588    93551  2018  2.526522e+06  3.684106e+06  6.507298e+07
# 1589    93552  2020  9.987008e+06  8.634139e+06  1.770726e+08
# 1590    93553  2020  3.218187e+05  5.229903e+07  1.477662e+08
# 1591    93563  2020  1.447706e+06  8.065865e+07  1.927201e+08
# 1592    93591  2020  6.673020e+06  3.750836e+06  2.419502e+08
#
#       vegetation_area    trees_%    grass_%  vegetation_%  trees_%_delta  \
# 0        9.553015e+05  13.637978  17.440777     31.078754            NaN
# 1        3.785107e+04   0.859533   0.371873      1.231406     -12.778444
# 2        1.841793e+05   3.284647   2.707245      5.991892       2.425114
# 3        2.548057e+05   7.582692   0.706885      8.289577       4.298045
# 4        8.047859e+04   1.898647   0.719557      2.618204      -5.684045
# ...               ...        ...        ...           ...            ...
# 1588     6.210628e+06   5.661499   3.882597      9.544096       2.135941
# 1589     1.862115e+07   4.876044   5.640063     10.516107            NaN
# 1590     5.262085e+07  35.393087   0.217789     35.610876            NaN
# 1591     8.210635e+07  41.852735   0.751196     42.603930            NaN
# 1592     1.042386e+07   1.550251   2.758014      4.308265            NaN
#
#       grass_%_delta  vegetation_%_delta  median_income  median_income_delta
# 0               NaN                 NaN        35097.0                  NaN
# 1        -17.068904          -29.847348        35658.0                561.0
# 2          2.335372            4.760486        34050.0              -1608.0
# 3         -2.000359            2.297685        34323.0                273.0
# 4          0.012672           -5.671373        38521.0               4198.0
# ...             ...                 ...            ...                  ...
# 1588       0.113645            2.249586        92500.0               8500.0
# 1589            NaN                 NaN        66289.0               3028.0
# 1590            NaN                 NaN        62875.0               5042.0
# 1591            NaN                 NaN       200625.0             117969.0
# 1592            NaN                 NaN        48911.0               2653.0
#
# [1593 rows x 14 columns]

# %% [markdown]
# ### Afluency Hypothesis

# %%
df_aff = df.dropna()

# %%
year_cat = pd.get_dummies(df_aff, columns=['year'])

# %%
df_aff_1 = pd.concat([df_aff, year_cat], axis=1)

# %%
df_aff_1.to_csv('df_aff_1.csv')

# %%
df_aff_1 = pd.read_csv('df_aff_1.csv')

# %%
df_aff_1['median_income_k'] = df_aff_1['median_income']/1000

# %%
df_aff_1['median_income_delta_k'] = df_aff_1['median_income_delta']/1000

# %%
y = df_aff_1[['vegetation_%_delta']]

# %%
x = df_aff_1[['median_income_k','median_income_delta_k','year_2012', 'year_2014', 'year_2016',
       'year_2018', 'year_2020']]

# %%
g = df_aff_1['year']

# %%
x = sm.add_constant(x)

# %%
model = sm.OLS(y, x)

# %%
results = model.fit()

# %%
rlm_model = sm.RLM(y, x, M=sm.robust.norms.HuberT())

rlm_results = rlm_model.fit()

# %%
import statsmodels.formula.api as smf

md = smf.mixedlm("'vegetation_%_delta'~'median_income_k'" , data = df_aff_1, groups=df_aff_1["year"])

mdf = md.fit()
# Out:
# ---------------------------------------------------------------------------
# PatsyError                                Traceback (most recent call last)
# Input In [134], in <cell line: 3>()
#       1 import statsmodels.formula.api as smf
# ----> 3 md = smf.mixedlm("'vegetation_%_delta'~'median_income'" , data = df_aff_1, groups=df_aff_1["year"])
#       5 mdf = md.fit()
#
# File ~\Anaconda3\envs\lawn\lib\site-packages\statsmodels\regression\mixed_linear_model.py:1046, in MixedLM.from_formula(cls, formula, data, re_formula, vc_formula, subset, use_sparse, missing, *args, **kwargs)
#    1044 kwargs["exog_vc"] = exog_vc
#    1045 kwargs["groups"] = groups
# -> 1046 mod = super(MixedLM, cls).from_formula(
#    1047     formula, data, *args, **kwargs)
#    1049 # expand re names to account for pairs of RE
#    1050 (param_names,
#    1051  exog_re_names,
#    1052  exog_re_names_full) = mod._make_param_names(exog_re_names)
#
# File ~\Anaconda3\envs\lawn\lib\site-packages\statsmodels\base\model.py:200, in Model.from_formula(cls, formula, data, subset, drop_cols, *args, **kwargs)
#     197 if missing == 'none':  # with patsy it's drop or raise. let's raise.
#     198     missing = 'raise'
# --> 200 tmp = handle_formula_data(data, None, formula, depth=eval_env,
#     201                           missing=missing)
#     202 ((endog, exog), missing_idx, design_info) = tmp
#     203 max_endog = cls._formula_max_endog
#
# File ~\Anaconda3\envs\lawn\lib\site-packages\statsmodels\formula\formulatools.py:63, in handle_formula_data(Y, X, formula, depth, missing)
#      61 else:
#      62     if data_util._is_using_pandas(Y, None):
# ---> 63         result = dmatrices(formula, Y, depth, return_type='dataframe',
#      64                            NA_action=na_action)
#      65     else:
#      66         result = dmatrices(formula, Y, depth, return_type='dataframe',
#      67                            NA_action=na_action)
#
# File ~\Anaconda3\envs\lawn\lib\site-packages\patsy\highlevel.py:309, in dmatrices(formula_like, data, eval_env, NA_action, return_type)
#     299 """Construct two design matrices given a formula_like and data.
#     300
#     301 This function is identical to :func:`dmatrix`, except that it requires
#    (...)
#     306 See :func:`dmatrix` for details.
#     307 """
#     308 eval_env = EvalEnvironment.capture(eval_env, reference=1)
# --> 309 (lhs, rhs) = _do_highlevel_design(formula_like, data, eval_env,
#     310                                   NA_action, return_type)
#     311 if lhs.shape[1] == 0:
#     312     raise PatsyError("model is missing required outcome variables")
#
# File ~\Anaconda3\envs\lawn\lib\site-packages\patsy\highlevel.py:167, in _do_highlevel_design(formula_like, data, eval_env, NA_action, return_type)
#     164 design_infos = _try_incr_builders(formula_like, data_iter_maker, eval_env,
#     165                                   NA_action)
#     166 if design_infos is not None:
# --> 167     return build_design_matrices(design_infos, data,
#     168                                  NA_action=NA_action,
#     169                                  return_type=return_type)
#     170 else:
#     171     # No builders, but maybe we can still get matrices
#     172     if isinstance(formula_like, tuple):
#
# File ~\Anaconda3\envs\lawn\lib\site-packages\patsy\build.py:893, in build_design_matrices(design_infos, data, NA_action, return_type, dtype)
#     891 name = factor_info.factor.name()
#     892 origin = factor_info.factor.origin
# --> 893 rows_checker.check(value.shape[0], name, origin)
#     894 if (have_pandas
#     895     and isinstance(value, (pandas.Series, pandas.DataFrame))):
#     896     index_checker.check(value.index, name, origin)
#
# File ~\Anaconda3\envs\lawn\lib\site-packages\patsy\build.py:795, in _CheckMatch.check(self, seen_value, desc, origin)
#     792     msg += " (%r versus %r)" % (self.value, seen_value)
#     793 # XX FIXME: this is a case where having discontiguous Origins
#     794 # would be useful...
# --> 795 raise PatsyError(msg, origin)
#
# PatsyError: Number of rows mismatch between data argument and 'vegetation_%_delta' (1232 versus 1)
#     'vegetation_%_delta'~'median_income'
#     ^^^^^^^^^^^^^^^^^^^^

# %%
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     vegetation_%_delta   R-squared:                       0.461
# Model:                            OLS   Adj. R-squared:                  0.459
# Method:                 Least Squares   F-statistic:                     209.6
# Date:                Mon, 25 Jul 2022   Prob (F-statistic):          1.19e-161
# Time:                        00:56:00   Log-Likelihood:                -4567.5
# No. Observations:                1232   AIC:                             9147.
# Df Residuals:                    1226   BIC:                             9178.
# Df Model:                           5
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const              -0.8487      0.608     -1.396      0.163      -2.042       0.344
# median_income_k     0.0364      0.010      3.734      0.000       0.017       0.056
# year_2012         -12.4088      0.569    -21.826      0.000     -13.524     -11.293
# year_2014           6.0224      0.566     10.649      0.000       4.913       7.132
# year_2016          -3.4518      0.572     -6.039      0.000      -4.573      -2.330
# year_2018          -4.3480      0.585     -7.430      0.000      -5.496      -3.200
# year_2020          13.3375      0.605     22.048      0.000      12.151      14.524
# ==============================================================================
# Omnibus:                      237.556   Durbin-Watson:                   2.313
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              987.924
# Skew:                           0.861   Prob(JB):                    2.99e-215
# Kurtosis:                       7.035   Cond. No.                     1.70e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.39e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
print(rlm_results.summary())
# Out:
#                     Robust linear Model Regression Results
# ==============================================================================
# Dep. Variable:     vegetation_%_delta   No. Observations:                 1232
# Model:                            RLM   Df Residuals:                     1226
# Method:                          IRLS   Df Model:                            5
# Norm:                          HuberT
# Scale Est.:                       mad
# Cov Type:                          H1
# Date:                Mon, 25 Jul 2022
# Time:                        00:56:00
# No. Iterations:                    23
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const              -0.1183      0.511     -0.231      0.817      -1.121       0.884
# median_income_k     0.0174      0.008      2.119      0.034       0.001       0.033
# year_2012         -14.0150      0.478    -29.313      0.000     -14.952     -13.078
# year_2014           6.5373      0.476     13.746      0.000       5.605       7.469
# year_2016          -3.2285      0.481     -6.717      0.000      -4.171      -2.287
# year_2018          -3.3813      0.492     -6.871      0.000      -4.346      -2.417
# year_2020          13.9693      0.509     27.460      0.000      12.972      14.966
# ===================================================================================
#
# If the model instance has been used for another fit with different fit parameters, then the fit options might not be the correct ones anymore .

# %%
print(mdf.summary())

# %%
df_aff_1.plot.scatter(x = 'median_income_k', y = 'vegetation_%_delta')
# Out:
# <AxesSubplot:xlabel='median_income_k', ylabel='vegetation_%_delta'>

# %%
df_aff_1.to_csv('results_lawn_final.csv')
